# %% [markdown]
# # Tutorial 2 - Compare models

# %% [markdown]
# In [Tutorial 1](./tutorial-1-how-to-run-a-model.ipynb), we saw how to run a PyBaMM simulation of the DFN model. However, PyBaMM includes other standard electrochemical models such as the Single Particle Model (SPM) and the Single Particle Model with electrolyte (SPMe). In this tutorial, we will see how to simulate and compare these three models.
#
# Again, the first step is to import PyBaMM into the notebook:

# %%
# !pip install --upgrade pybtex
# !pip install --upgrade setuptools wheel
# !pip install --force-reinstall "pybamm[plot,cite]"
# Out:
# Requirement already satisfied: pybtex in /usr/local/lib/python3.11/dist-packages (0.24.0)
# Requirement already satisfied: PyYAML>=3.01 in /usr/local/lib/python3.11/dist-packages (from pybtex) (6.0.2)
# Requirement already satisfied: latexcodec>=1.0.4 in /usr/local/lib/python3.11/dist-packages (from pybtex) (3.0.0)
# Requirement already satisfied: six in /usr/local/lib/python3.11/dist-packages (from pybtex) (1.17.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (80.9.0)
# Requirement already satisfied: wheel in /usr/local/lib/python3.11/dist-packages (0.45.1)
# Collecting pybamm[cite,plot]
#   Using cached pybamm-25.6.0-py3-none-any.whl.metadata (15 kB)
# Collecting anytree>=2.8.0 (from pybamm[cite,plot])
#   Using cached anytree-2.13.0-py3-none-any.whl.metadata (8.0 kB)
# Collecting casadi==3.6.7 (from pybamm[cite,plot])
#   Using cached casadi-3.6.7-cp311-none-manylinux2014_x86_64.whl.metadata (2.2 kB)
# Collecting numpy<2.0.0,>=1.23.5 (from pybamm[cite,plot])
#   Using cached numpy-1.26.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
# Collecting pandas>=1.5.0 (from pybamm[cite,plot])
#   Downloading pandas-2.3.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (91 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 91.2/91.2 kB 2.3 MB/s eta 0:00:00
# Collecting platformdirs (from pybamm[cite,plot])
#   Downloading platformdirs-4.3.8-py3-none-any.whl.metadata (12 kB)
# Collecting pooch>=1.8.1 (from pybamm[cite,plot])
#   Downloading pooch-1.8.2-py3-none-any.whl.metadata (10 kB)
# Collecting posthog (from pybamm[cite,plot])
#   Using cached posthog-4.6.2-py3-none-any.whl.metadata (5.9 kB)
# Collecting pybammsolvers (from pybamm[cite,plot])
#   Using cached pybammsolvers-0.1.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.0 kB)
# Collecting pyyaml (from pybamm[cite,plot])
#   Downloading PyYAML-6.0.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.1 kB)
# Collecting scipy>=1.11.4 (from pybamm[cite,plot])
#   Downloading scipy-1.15.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.0/62.0 kB 3.0 MB/s eta 0:00:00
# Collecting sympy>=1.12 (from pybamm[cite,plot])
#   Downloading sympy-1.14.0-py3-none-any.whl.metadata (12 kB)
# Collecting typing-extensions>=4.10.0 (from pybamm[cite,plot])
#   Downloading typing_extensions-4.14.0-py3-none-any.whl.metadata (3.0 kB)
# Collecting xarray>=2022.6.0 (from pybamm[cite,plot])
#   Downloading xarray-2025.6.0-py3-none-any.whl.metadata (12 kB)
# Collecting pybtex>=0.24.0 (from pybamm[cite,plot])
#   Using cached pybtex-0.24.0-py2.py3-none-any.whl.metadata (2.0 kB)
# Collecting setuptools (from pybamm[cite,plot])
#   Using cached setuptools-80.9.0-py3-none-any.whl.metadata (6.6 kB)
# Collecting matplotlib>=3.6.0 (from pybamm[cite,plot])
#   Downloading matplotlib-3.10.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (11 kB)
# Collecting contourpy>=1.0.1 (from matplotlib>=3.6.0->pybamm[cite,plot])
#   Downloading contourpy-1.3.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.5 kB)
# Collecting cycler>=0.10 (from matplotlib>=3.6.0->pybamm[cite,plot])
#   Downloading cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib>=3.6.0->pybamm[cite,plot])
#   Downloading fonttools-4.58.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (106 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 106.3/106.3 kB 3.9 MB/s eta 0:00:00
# Collecting kiwisolver>=1.3.1 (from matplotlib>=3.6.0->pybamm[cite,plot])
#   Downloading kiwisolver-1.4.8-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.2 kB)
# Collecting packaging>=20.0 (from matplotlib>=3.6.0->pybamm[cite,plot])
#   Downloading packaging-25.0-py3-none-any.whl.metadata (3.3 kB)
# Collecting pillow>=8 (from matplotlib>=3.6.0->pybamm[cite,plot])
#   Downloading pillow-11.2.1-cp311-cp311-manylinux_2_28_x86_64.whl.metadata (8.9 kB)
# Collecting pyparsing>=2.3.1 (from matplotlib>=3.6.0->pybamm[cite,plot])
#   Downloading pyparsing-3.2.3-py3-none-any.whl.metadata (5.0 kB)
# Collecting python-dateutil>=2.7 (from matplotlib>=3.6.0->pybamm[cite,plot])
#   Downloading python_dateutil-2.9.0.post0-py2.py3-none-any.whl.metadata (8.4 kB)
# Collecting pytz>=2020.1 (from pandas>=1.5.0->pybamm[cite,plot])
#   Downloading pytz-2025.2-py2.py3-none-any.whl.metadata (22 kB)
# Collecting tzdata>=2022.7 (from pandas>=1.5.0->pybamm[cite,plot])
#   Downloading tzdata-2025.2-py2.py3-none-any.whl.metadata (1.4 kB)
# Collecting requests>=2.19.0 (from pooch>=1.8.1->pybamm[cite,plot])
#   Downloading requests-2.32.4-py3-none-any.whl.metadata (4.9 kB)
# Collecting latexcodec>=1.0.4 (from pybtex>=0.24.0->pybamm[cite,plot])
#   Using cached latexcodec-3.0.0-py3-none-any.whl.metadata (4.9 kB)
# Collecting six (from pybtex>=0.24.0->pybamm[cite,plot])
#   Downloading six-1.17.0-py2.py3-none-any.whl.metadata (1.7 kB)
# Collecting mpmath<1.4,>=1.1.0 (from sympy>=1.12->pybamm[cite,plot])
#   Downloading mpmath-1.3.0-py3-none-any.whl.metadata (8.6 kB)
# Collecting backoff>=1.10.0 (from posthog->pybamm[cite,plot])
#   Using cached backoff-2.2.1-py3-none-any.whl.metadata (14 kB)
# Collecting distro>=1.5.0 (from posthog->pybamm[cite,plot])
#   Downloading distro-1.9.0-py3-none-any.whl.metadata (6.8 kB)
# Collecting charset_normalizer<4,>=2 (from requests>=2.19.0->pooch>=1.8.1->pybamm[cite,plot])
#   Downloading charset_normalizer-3.4.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (35 kB)
# Collecting idna<4,>=2.5 (from requests>=2.19.0->pooch>=1.8.1->pybamm[cite,plot])
#   Downloading idna-3.10-py3-none-any.whl.metadata (10 kB)
# Collecting urllib3<3,>=1.21.1 (from requests>=2.19.0->pooch>=1.8.1->pybamm[cite,plot])
#   Downloading urllib3-2.4.0-py3-none-any.whl.metadata (6.5 kB)
# Collecting certifi>=2017.4.17 (from requests>=2.19.0->pooch>=1.8.1->pybamm[cite,plot])
#   Downloading certifi-2025.4.26-py3-none-any.whl.metadata (2.5 kB)
# Using cached casadi-3.6.7-cp311-none-manylinux2014_x86_64.whl (73.4 MB)
# Using cached anytree-2.13.0-py3-none-any.whl (45 kB)
# Downloading matplotlib-3.10.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (8.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.6/8.6 MB 6.9 MB/s eta 0:00:00
# Using cached numpy-1.26.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.3 MB)
# Downloading pandas-2.3.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (12.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.4/12.4 MB 6.8 MB/s eta 0:00:00
# Downloading pooch-1.8.2-py3-none-any.whl (64 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.6/64.6 kB 5.6 MB/s eta 0:00:00
# Downloading platformdirs-4.3.8-py3-none-any.whl (18 kB)
# Using cached pybtex-0.24.0-py2.py3-none-any.whl (561 kB)
# Downloading PyYAML-6.0.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (762 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 763.0/763.0 kB 10.6 MB/s eta 0:00:00
# Downloading scipy-1.15.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (37.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 37.7/37.7 MB 13.4 MB/s eta 0:00:00
# Downloading sympy-1.14.0-py3-none-any.whl (6.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.3/6.3 MB 20.2 MB/s eta 0:00:00
# Downloading typing_extensions-4.14.0-py3-none-any.whl (43 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.8/43.8 kB 3.8 MB/s eta 0:00:00
# Downloading xarray-2025.6.0-py3-none-any.whl (1.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 16.1 MB/s eta 0:00:00
# Using cached posthog-4.6.2-py3-none-any.whl (101 kB)
# Using cached pybamm-25.6.0-py3-none-any.whl (772 kB)
# Using cached pybammsolvers-0.1.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (15.9 MB)
# Using cached setuptools-80.9.0-py3-none-any.whl (1.2 MB)
# Using cached backoff-2.2.1-py3-none-any.whl (15 kB)
# Downloading contourpy-1.3.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (326 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 326.2/326.2 kB 10.8 MB/s eta 0:00:00
# Downloading cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading distro-1.9.0-py3-none-any.whl (20 kB)
# Downloading fonttools-4.58.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 15.1 MB/s eta 0:00:00
# Downloading kiwisolver-1.4.8-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 14.1 MB/s eta 0:00:00
# Using cached latexcodec-3.0.0-py3-none-any.whl (18 kB)
# Downloading mpmath-1.3.0-py3-none-any.whl (536 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 536.2/536.2 kB 12.1 MB/s eta 0:00:00
# Downloading packaging-25.0-py3-none-any.whl (66 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.5/66.5 kB 3.7 MB/s eta 0:00:00
# Downloading pillow-11.2.1-cp311-cp311-manylinux_2_28_x86_64.whl (4.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.6/4.6 MB 15.5 MB/s eta 0:00:00
# Downloading pyparsing-3.2.3-py3-none-any.whl (111 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 111.1/111.1 kB 7.9 MB/s eta 0:00:00
# Downloading python_dateutil-2.9.0.post0-py2.py3-none-any.whl (229 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 229.9/229.9 kB 8.0 MB/s eta 0:00:00
# Downloading pytz-2025.2-py2.py3-none-any.whl (509 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 509.2/509.2 kB 10.1 MB/s eta 0:00:00
# Downloading requests-2.32.4-py3-none-any.whl (64 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.8/64.8 kB 5.4 MB/s eta 0:00:00
# Downloading six-1.17.0-py2.py3-none-any.whl (11 kB)
# Downloading tzdata-2025.2-py2.py3-none-any.whl (347 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 347.8/347.8 kB 7.8 MB/s eta 0:00:00
# Downloading certifi-2025.4.26-py3-none-any.whl (159 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 159.6/159.6 kB 5.7 MB/s eta 0:00:00
# Downloading charset_normalizer-3.4.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (147 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 147.3/147.3 kB 5.5 MB/s eta 0:00:00
# Downloading idna-3.10-py3-none-any.whl (70 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 70.4/70.4 kB 5.1 MB/s eta 0:00:00
# Downloading urllib3-2.4.0-py3-none-any.whl (128 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 128.7/128.7 kB 5.2 MB/s eta 0:00:00
# Installing collected packages: pytz, mpmath, urllib3, tzdata, typing-extensions, sympy, six, setuptools, pyyaml, pyparsing, platformdirs, pillow, packaging, numpy, latexcodec, kiwisolver, idna, fonttools, distro, cycler, charset_normalizer, certifi, backoff, anytree, scipy, requests, python-dateutil, pybtex, contourpy, casadi, pybammsolvers, posthog, pooch, pandas, matplotlib, xarray, pybamm
#   Attempting uninstall: pytz
#     Found existing installation: pytz 2025.2
#     Uninstalling pytz-2025.2:
#       Successfully uninstalled pytz-2025.2
#   Attempting uninstall: mpmath
#     Found existing installation: mpmath 1.3.0
#     Uninstalling mpmath-1.3.0:
#       Successfully uninstalled mpmath-1.3.0
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 2.4.0
#     Uninstalling urllib3-2.4.0:
#       Successfully uninstalled urllib3-2.4.0
#   Attempting uninstall: tzdata
#     Found existing installation: tzdata 2025.2
#     Uninstalling tzdata-2025.2:
#       Successfully uninstalled tzdata-2025.2
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing_extensions 4.14.0
#     Uninstalling typing_extensions-4.14.0:
#       Successfully uninstalled typing_extensions-4.14.0
#   Attempting uninstall: sympy
#     Found existing installation: sympy 1.13.1
#     Uninstalling sympy-1.13.1:
#       Successfully uninstalled sympy-1.13.1
#   Attempting uninstall: six
#     Found existing installation: six 1.17.0
#     Uninstalling six-1.17.0:
#       Successfully uninstalled six-1.17.0
#   Attempting uninstall: setuptools
#     Found existing installation: setuptools 80.9.0
#     Uninstalling setuptools-80.9.0:
#       Successfully uninstalled setuptools-80.9.0
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 6.0.2
#     Uninstalling PyYAML-6.0.2:
#       Successfully uninstalled PyYAML-6.0.2
#   Attempting uninstall: pyparsing
#     Found existing installation: pyparsing 3.2.3
#     Uninstalling pyparsing-3.2.3:
#       Successfully uninstalled pyparsing-3.2.3
#   Attempting uninstall: platformdirs
#     Found existing installation: platformdirs 4.3.8
#     Uninstalling platformdirs-4.3.8:
#       Successfully uninstalled platformdirs-4.3.8
#   Attempting uninstall: pillow
#     Found existing installation: pillow 11.2.1
#     Uninstalling pillow-11.2.1:
#       Successfully uninstalled pillow-11.2.1
#   Attempting uninstall: packaging
#     Found existing installation: packaging 24.2
#     Uninstalling packaging-24.2:
#       Successfully uninstalled packaging-24.2
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.26.4
#     Uninstalling numpy-1.26.4:
#       Successfully uninstalled numpy-1.26.4
#   Attempting uninstall: latexcodec
#     Found existing installation: latexcodec 3.0.0
#     Uninstalling latexcodec-3.0.0:
#       Successfully uninstalled latexcodec-3.0.0
#   Attempting uninstall: kiwisolver
#     Found existing installation: kiwisolver 1.4.8
#     Uninstalling kiwisolver-1.4.8:
#       Successfully uninstalled kiwisolver-1.4.8
#   Attempting uninstall: idna
#     Found existing installation: idna 3.10
#     Uninstalling idna-3.10:
#       Successfully uninstalled idna-3.10
#   Attempting uninstall: fonttools
#     Found existing installation: fonttools 4.58.1
#     Uninstalling fonttools-4.58.1:
#       Successfully uninstalled fonttools-4.58.1
#   Attempting uninstall: distro
#     Found existing installation: distro 1.9.0
#     Uninstalling distro-1.9.0:
#       Successfully uninstalled distro-1.9.0
#   Attempting uninstall: cycler
#     Found existing installation: cycler 0.12.1
#     Uninstalling cycler-0.12.1:
#       Successfully uninstalled cycler-0.12.1
#   Attempting uninstall: charset_normalizer
#     Found existing installation: charset-normalizer 3.4.2
#     Uninstalling charset-normalizer-3.4.2:
#       Successfully uninstalled charset-normalizer-3.4.2
#   Attempting uninstall: certifi
#     Found existing installation: certifi 2025.4.26
#     Uninstalling certifi-2025.4.26:
#       Successfully uninstalled certifi-2025.4.26
#   Attempting uninstall: backoff
#     Found existing installation: backoff 2.2.1
#     Uninstalling backoff-2.2.1:
#       Successfully uninstalled backoff-2.2.1
#   Attempting uninstall: anytree
#     Found existing installation: anytree 2.13.0
#     Uninstalling anytree-2.13.0:
#       Successfully uninstalled anytree-2.13.0
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.15.3
#     Uninstalling scipy-1.15.3:
#       Successfully uninstalled scipy-1.15.3
#   Attempting uninstall: requests
#     Found existing installation: requests 2.32.3
#     Uninstalling requests-2.32.3:
#       Successfully uninstalled requests-2.32.3
#   Attempting uninstall: python-dateutil
#     Found existing installation: python-dateutil 2.9.0.post0
#     Uninstalling python-dateutil-2.9.0.post0:
#       Successfully uninstalled python-dateutil-2.9.0.post0
#   Attempting uninstall: pybtex
#     Found existing installation: pybtex 0.24.0
#     Uninstalling pybtex-0.24.0:
#       Successfully uninstalled pybtex-0.24.0
#   Attempting uninstall: contourpy
#     Found existing installation: contourpy 1.3.2
#     Uninstalling contourpy-1.3.2:
#       Successfully uninstalled contourpy-1.3.2
#   Attempting uninstall: casadi
#     Found existing installation: casadi 3.6.7
#     Uninstalling casadi-3.6.7:
#       Successfully uninstalled casadi-3.6.7
#   Attempting uninstall: pybammsolvers
#     Found existing installation: pybammsolvers 0.1.0
#     Uninstalling pybammsolvers-0.1.0:
#       Successfully uninstalled pybammsolvers-0.1.0
#   Attempting uninstall: posthog
#     Found existing installation: posthog 4.6.2
#     Uninstalling posthog-4.6.2:
#       Successfully uninstalled posthog-4.6.2
#   Attempting uninstall: pooch
#     Found existing installation: pooch 1.8.2
#     Uninstalling pooch-1.8.2:
#       Successfully uninstalled pooch-1.8.2
#   Attempting uninstall: pandas
#     Found existing installation: pandas 2.2.2
#     Uninstalling pandas-2.2.2:
#       Successfully uninstalled pandas-2.2.2
#   Attempting uninstall: matplotlib
#     Found existing installation: matplotlib 3.10.0
#     Uninstalling matplotlib-3.10.0:
#       Successfully uninstalled matplotlib-3.10.0
#   Attempting uninstall: xarray
#     Found existing installation: xarray 2025.3.1
#     Uninstalling xarray-2025.3.1:
#       Successfully uninstalled xarray-2025.3.1
#   Attempting uninstall: pybamm
#     Found existing installation: pybamm 25.6.0
#     Uninstalling pybamm-25.6.0:
#       Successfully uninstalled pybamm-25.6.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ipython 7.34.0 requires jedi>=0.16, which is not installed.
# google-colab 1.0.0 requires pandas==2.2.2, but you have pandas 2.3.0 which is incompatible.
# google-colab 1.0.0 requires requests==2.32.3, but you have requests 2.32.4 which is incompatible.
# cudf-cu12 25.2.1 requires pandas<2.2.4dev0,>=2.0, but you have pandas 2.3.0 which is incompatible.
# dask-cudf-cu12 25.2.2 requires pandas<2.2.4dev0,>=2.0, but you have pandas 2.3.0 which is incompatible.
# langchain-core 0.3.63 requires packaging<25,>=23.2, but you have packaging 25.0 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-cublas-cu12==12.4.5.8; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cublas-cu12 12.5.3.2 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-cuda-cupti-cu12==12.4.127; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cuda-cupti-cu12 12.5.82 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-cuda-nvrtc-cu12==12.4.127; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cuda-nvrtc-cu12 12.5.82 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-cuda-runtime-cu12==12.4.127; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cuda-runtime-cu12 12.5.82 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-cudnn-cu12==9.1.0.70; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cudnn-cu12 9.3.0.75 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-cufft-cu12==11.2.1.3; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cufft-cu12 11.2.3.61 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-curand-cu12==10.3.5.147; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-curand-cu12 10.3.6.82 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-cusolver-cu12==11.6.1.9; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cusolver-cu12 11.6.3.83 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-cusparse-cu12==12.3.1.170; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cusparse-cu12 12.5.1.3 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-nvjitlink-cu12==12.4.127; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-nvjitlink-cu12 12.5.82 which is incompatible.
# torch 2.6.0+cu124 requires sympy==1.13.1; python_version >= "3.9", but you have sympy 1.14.0 which is incompatible.
# thinc 8.3.6 requires numpy<3.0.0,>=2.0.0, but you have numpy 1.26.4 which is incompatible.
# Successfully installed anytree-2.13.0 backoff-2.2.1 casadi-3.6.7 certifi-2025.4.26 charset_normalizer-3.4.2 contourpy-1.3.2 cycler-0.12.1 distro-1.9.0 fonttools-4.58.2 idna-3.10 kiwisolver-1.4.8 latexcodec-3.0.0 matplotlib-3.10.3 mpmath-1.3.0 numpy-1.26.4 packaging-25.0 pandas-2.3.0 pillow-11.2.1 platformdirs-4.3.8 pooch-1.8.2 posthog-4.6.2 pybamm-25.6.0 pybammsolvers-0.1.0 pybtex-0.24.0 pyparsing-3.2.3 python-dateutil-2.9.0.post0 pytz-2025.2 pyyaml-6.0.2 requests-2.32.4 scipy-1.15.3 setuptools-80.9.0 six-1.17.0 sympy-1.14.0 typing-extensions-4.14.0 tzdata-2025.2 urllib3-2.4.0 xarray-2025.6.0

# %%
# %pip install "pybamm[plot,cite]" -q    # install PyBaMM if it is not installed
import pybamm
# Out:
# PyBaMM can collect usage data and send it to the PyBaMM team to help us improve the software.
# We do not collect any sensitive information such as models, parameters, or simulation results - only information on which parts of the code are being used and how frequently.
# This is entirely optional and does not impact the functionality of PyBaMM.
# For more information, see https://docs.pybamm.org/en/latest/source/user_guide/index.html#telemetry
# Do you want to enable telemetry? (Y/n): y
#
# Telemetry enabled.

# %% [markdown]
# As we want to compare various models, we now create a list of all the models we wish to solve:

# %%
models = [
    pybamm.lithium_ion.SPM(),
    pybamm.lithium_ion.SPMe(),
    pybamm.lithium_ion.DFN(),
]

# %% [markdown]
# We will loop over the list, creating and solving simulations as we go (in the same way we learned in [Tutorial 1](./tutorial-1-how-to-run-a-model.ipynb)), and storing the solved simulations in the list `sims`:

# %%
sims = []
for model in models:
    sim = pybamm.Simulation(model)
    sim.solve([0, 3600])
    sims.append(sim)
# Out:
# /usr/local/lib/python3.11/dist-packages/pybamm/simulation.py:120: UserWarning: The default solver changed to IDAKLUSolver after the v25.4.0. release. You can swap back to the previous default by using `pybamm.CasadiSolver()` instead.
#   self._solver = solver or self._model.default_solver

# %% [markdown]
# We can now pass our list of simulations to the `dynamic_plot` method, which has similar syntax to the `sim.plot()` method we used earlier and will plot the different solutions in the same figure:

# %%
pybamm.dynamic_plot(sims)
# Out:
# interactive(children=(FloatSlider(value=0.0, description='t', max=1.0, step=0.01), Output()), _dom_classes=('w…

# %% [markdown]
# In this tutorial we have seen how easy it is to run and compare different electrochemical models. In [Tutorial 3](./tutorial-3-basic-plotting.ipynb) we show how to create different plots using PyBaMM's built-in plotting capability.

# %% [markdown]
# ## References
#
# The relevant papers for this notebook are:

# %%
pybamm.print_citations()
# Out:
# [1] Joel A. E. Andersson, Joris Gillis, Greg Horn, James B. Rawlings, and Moritz Diehl. CasADi – A software framework for nonlinear optimization and optimal control. Mathematical Programming Computation, 11(1):1–36, 2019. doi:10.1007/s12532-018-0139-4.
# [2] Marc Doyle, Thomas F. Fuller, and John Newman. Modeling of galvanostatic charge and discharge of the lithium/polymer/insertion cell. Journal of the Electrochemical society, 140(6):1526–1533, 1993. doi:10.1149/1.2221597.
# [3] Charles R. Harris, K. Jarrod Millman, Stéfan J. van der Walt, Ralf Gommers, Pauli Virtanen, David Cournapeau, Eric Wieser, Julian Taylor, Sebastian Berg, Nathaniel J. Smith, and others. Array programming with NumPy. Nature, 585(7825):357–362, 2020. doi:10.1038/s41586-020-2649-2.
# [4] Scott G. Marquis, Valentin Sulzer, Robert Timms, Colin P. Please, and S. Jon Chapman. An asymptotic derivation of a single particle model with electrolyte. Journal of The Electrochemical Society, 166(15):A3693–A3706, 2019. doi:10.1149/2.0341915jes.
# [5] Valentin Sulzer, Scott G. Marquis, Robert Timms, Martin Robinson, and S. Jon Chapman. Python Battery Mathematical Modelling (PyBaMM). Journal of Open Research Software, 9(1):14, 2021. doi:10.5334/jors.309.
